# %% [markdown]
# # Setup
#
# Make sure you have the following prerequisites installed on your system:

# %%
# %%bash
# ## SETUP FOR PYTHON ENVIRONMENT
# # pip install --upgrade pip
# # pip install --upgrade ipykernel
# # pip install --upgrade traitlets
# # pip install fastapi[all]
# # pip install --upgrade typing_extensions
# # pip install prompt_toolkit
# Out:
# Requirement already satisfied: typing_extensions in /home/iissa/.miniconda3/envs/sage-env/lib/python3.10/site-packages (4.15.0)

# %%
# %%bash
# cd ../backend/app
# python TestTicketService.py
# Out:
# {'title': 'Test Ticket', 'description': 'This is a test ticket.', 'status': 'open', 'id': '11', 'created_at': '2026-01-09T20:10:55.782277'}
# {'detail': 'Ticket title cannot be empty.'} 422
# {'detail': [{'type': 'string_too_short', 'loc': ['body', 'description'], 'msg': 'String should have at least 1 character', 'input': '', 'ctx': {'min_length': 1}}]} 422
# {'detail': [{'type': 'literal_error', 'loc': ['body', 'status'], 'msg': "Input should be 'open', 'in_progress' or 'closed'", 'input': 'invalid_status', 'ctx': {'expected': "'open', 'in_progress' or 'closed'"}}]} 422
# Ticket 11 status updated to closed.
# {'title': 'Test Ticket', 'description': 'This is a test ticket.', 'status': 'closed', 'id': '11', 'created_at': '2026-01-09T20:10:55.782277'}
# All tests passed.

# %% [markdown]
# # Setup
#
# Make sure you have the following prerequisites installed on your system:

# %%
# %%bash
# ## SETUP FOR PYTHON ENVIRONMENT
# # pip install --upgrade pip
# # pip install fastapi[all]
# # pip install --upgrade typing_extensions
# # pip install prompt_toolkit

# %% [markdown]
# # Running the Demo

# %%
# %%bash
# #%load_ext autoreload
# #%autoreload 2
# cd ../backend/app
# python TestTicketService.py
# Out:
# ____________________________________________________________________________________________________
# TEST: CREATE TICKET
#
# Creating ticket with title 'Test Ticket' and description 'This is a test ticket:'
#
# {'title': 'Test Ticket', 'description': 'This is a test ticket.', 'status': 'open', 'id': '11', 'created_at': '2026-01-09T21:12:30.058933'}
#
#
# ____________________________________________________________________________________________________
# TEST: ERROR CREATE TICKET
#
# Creating tickets with invalid data to test error handling:
# .
# {'detail': 'Ticket title cannot be empty.'} 422
# {'detail': [{'type': 'string_too_short', 'loc': ['body', 'description'], 'msg': 'String should have at least 1 character', 'input': '', 'ctx': {'min_length': 1}}]} 422
# {'detail': [{'type': 'literal_error', 'loc': ['body', 'status'], 'msg': "Input should be 'open', 'in_progress' or 'closed'", 'input': 'invalid_status', 'ctx': {'expected': "'open', 'in_progress' or 'closed'"}}]} 422
# ..
# ...

# %%
# %%bash
# cd ../frontend/src
# tail -n +1  App.tsx api/client.ts components/{ErrorFallback,Modal,TicketList,TicketDetails,TicketForm}.tsx types.ts
# Out:
# ==> App.tsx <==
# import { BrowserRouter, Routes, Route } from 'react-router-dom';
# import { QueryClient, QueryClientProvider } from '@tanstack/react-query';
# import { ErrorBoundary } from 'react-error-boundary';
# import { ErrorFallback } from './components/ErrorFallback';
# import './App.css'
# import TicketListPage from './components/TicketList'
# import TicketForm from './components/TicketForm'
# import TicketDetails from './components/TicketDetails'
#
# function App() {
#
# const queryClient = new QueryClient({
#                           defaultOptions: {
#                             queries: {
#                               throwOnError: true, // This bridges React Query and Error Boundaries
#                             },
#                             mutations: {
#                               throwOnError: true,
#                             }
#                           },
#                       });
#
#   return (
#     <>
# ...

# %%
# %%bash
# # cd ../docs
# # ffmpeg -i demo.mp4 -ss 00:00:00 -t 18 -vf "fps=15,scale=1920:-1:flags=lanczos,split[s0][s1];[s0]palettegen[p];[s1][p]paletteuse" demo.gif
# Out:
# ffmpeg version n4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix= --prefix=/usr --disable-debug --disable-doc --disable-static --enable-cuda --enable-cuda-sdk --enable-cuvid --enable-libdrm --enable-ffplay --enable-gnutls --enable-gpl --enable-libass --enable-libfdk-aac --enable-libfontconfig --enable-libfreetype --enable-libmp3lame --enable-libnpp --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopus --enable-libpulse --enable-sdl2 --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libv4l2 --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxvid --enable-nonfree --enable-nvenc --enable-omx --enable-openal --enable-opencl --enable-runtime-cpudetect --enable-shared --enable-vaapi --enable-vdpau --enable-version3 --enable-xlib
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
# ...
